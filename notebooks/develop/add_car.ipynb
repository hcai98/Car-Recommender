# %%
import pandas as pd

# %%
input_path = '../../data/processed/labels.csv'

# %%
cars = pd.read_csv(input_path)
# cars.columns = [col.strip().lower() for col in cars.columns]
car_dict_list = cars.to_dict(orient='records')

for car_dict in car_dict_list:
    print(car_dict)
# Out:
# {'car_id': 0, 'maker': 'Abarth', 'genmodel': '124 Spider', 'year': 2017, 'bodytype': 'Convertible', 'genmodel_id': '2_1', 'engin_size': 1.4, 'gearbox': 'Automatic', 'fuel_type': 'Petrol', 'price': 24479.166666666668, 'seat_num': 2.0, 'door_num': 2.0, 'class': 12}
# {'car_id': 1, 'maker': 'Abarth', 'genmodel': '124 Spider', 'year': 2018, 'bodytype': 'Convertible', 'genmodel_id': '2_1', 'engin_size': 1.4, 'gearbox': 'Automatic', 'fuel_type': 'Petrol', 'price': 23656.875, 'seat_num': 2.0, 'door_num': 2.0, 'class': 12}
# {'car_id': 2, 'maker': 'Abarth', 'genmodel': '124 Spider', 'year': 2021, 'bodytype': 'Convertible', 'genmodel_id': '2_1', 'engin_size': 1.4, 'gearbox': 'Automatic', 'fuel_type': 'Petrol', 'price': 20668.166666666668, 'seat_num': 2.0, 'door_num': 2.0, 'class': 12}
# ...

# %%
cars
# Out:
#       car_id   maker    genmodel  year     bodytype genmodel_id  engin_size  \
# 0          0  Abarth  124 Spider  2017  Convertible         2_1         1.4
# 1          1  Abarth  124 Spider  2018  Convertible         2_1         1.4
# 2          2  Abarth  124 Spider  2021  Convertible         2_1         1.4
# 3          3  Abarth         595  2016    Hatchback         2_4         1.4
# 4          4  Abarth         595  2017    Hatchback         2_4         1.4
# ...      ...     ...         ...   ...          ...         ...         ...
# 2863    2863   Volvo        XC90  2017          SUV       96_18         2.4
# 2864    2864   Volvo        XC90  2018       Estate       96_18         2.0
# 2865    2865   Volvo        XC90  2018          SUV       96_18         2.4
# 2866    2866   Volvo        XC90  2020          SUV       96_18         2.0
# 2867    2867   Volvo        XC90  2021          SUV       96_18         2.0
#
# ...
